# %%
import pandas as pd

# %%
movies_metadata = pd.read_csv('movies_metadata.csv', low_memory=False)
ratings = pd.read_csv('ratings.csv')

# %%
movies_metadata.head(5)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
ratings.head(5)
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
movies_metadata.sample(n=5)
# Out:
#        adult                              belongs_to_collection budget  \
# 10362  False                                                NaN      0
# 22825  False                                                NaN      0
# 12986  False                                                NaN      0
# 44104  False                                                NaN      0
# 30450  False  {'id': 394316, 'name': 'Johnny Tsunami Collect...      0
#
#                                                   genres  \
# 10362  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 22825  [{'id': 14, 'name': 'Fantasy'}, {'id': 16, 'na...
# 12986                                                 []
# 44104  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 30450  [{'id': 10770, 'name': 'TV Movie'}, {'id': 107...
#
#                                   homepage      id    imdb_id  \
# 10362                                  NaN   61044  tt0066612
# 22825      http://www.letableau-lefilm.fr/   98162  tt1891769
# 12986  http://www.sexoamoretraicao.com.br/  131805  tt0376873
# 44104                                  NaN   62721  tt0814236
# 30450                                  NaN   24020  tt0206064
#
#       original_language             original_title  \
# 10362                it  Vamos a matar, compañeros
# 22825                fr                 Le Tableau
# 12986                en       Sexo, Amor e Traição
# 44104                en           Obratnyy Otschet
# 30450                en             Johnny Tsunami
#
#                                                 overview  ... release_date  \
# 10362  Arms dealer Yolaf Peterson aims to make a sale...  ...   1970-12-18
# 22825  Three characters living in an unfinished paint...  ...   2011-11-22
# 12986  The story of two couples who are neighbors and...  ...   2004-01-02
# 44104  There will be an explosion exactly in 48 hours...  ...   2006-11-02
# 30450  A Hawaiian teenage surfer shows off his skills...  ...   1999-07-24
#
#        revenue runtime                                   spoken_languages  \
# 10362      0.0   118.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 22825  11229.0    76.0          [{'iso_639_1': 'fr', 'name': 'Français'}]
# 12986      0.0    90.0         [{'iso_639_1': 'pt', 'name': 'Português'}]
# 44104      0.0   110.0           [{'iso_639_1': 'ru', 'name': 'Pусский'}]
# 30450      0.0    88.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                      tagline  \
# 10362  Released                                          NaN
# 22825  Released          Break on through to the other side.
# 12986  Released                                          NaN
# 44104  Released                                          NaN
# 30450  Released  The Temperature Is Down But The Surf Is Up!
#
#                       title  video vote_average vote_count
# 10362            Companeros  False          6.7       16.0
# 22825          The Painting  False          7.3       35.0
# 12986  Sexo, Amor e Traição  False          6.2        5.0
# 44104             Countdown  False          5.3        3.0
# 30450        Johnny Tsunami  False          5.1       20.0
#
# [5 rows x 24 columns]

# %%
ratings.sample(n=5)
# Out:
#           userId  movieId  rating   timestamp
# 2618006    27245     3759     3.0  1195066037
# 25075642  260915     3527     3.5  1111486234
# 2306372    23953     1079     4.0   850426976
# 16238280  168755     1923     4.0  1213798826
# 17662861  183181   146327     3.5  1479817892
